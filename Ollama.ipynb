# %%
# ollama pull llama3.2:3b
# ollama pull qwen3:4b
import requests

try:
    response = requests.get("http://localhost:11434")
    print("Ollama is running!")
except:
    print("Ollama is NOT running.")
    print("Start Ollama before continuing.")
# Out:
# Ollama is running!

# %%
import requests

response = requests.get("http://localhost:11434/api/tags")

models = response.json()["models"]

print("Installed Models:\n")

for model in models:
    print(model["name"])
# Out:
# Installed Models:
#
# llama3.2:3b

# %% [markdown]
# !pip install ollama -q

# %%
from ollama import chat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from ollama import chat
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# First Prompt - create chatbot using ollama
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"What is Artificial Intelligence?"
        }
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # First Prompt - create chatbot using ollama
# ----> 2 response = chat(
#       3     model="llama3.2:3b",
#       4     messages=[
#       5         {
#
# NameError: name 'chat' is not defined

# %%
# Multiturn conversation
messages = [
    {
        "role":"user",
        "content":"What is Machine Learning?"
    }
]

response = chat(
    model="llama3.2:3b",
    messages=messages
)

answer = response["message"]["content"]

print(answer)

messages.append(
    {
        "role":"assistant",
        "content":answer
    }
)

messages.append(
    {
        "role":"user",
        "content":"Give one real-world example."
    }
)

response = chat(
    model="llama3.2:3b",
    messages=messages
)

print(response["message"]["content"])
# Out:
# Machine learning (ML) is a type of artificial intelligence (AI) that enables systems to learn and improve from experience without being explicitly programmed. It's a subset of AI that involves developing algorithms and statistical models that allow machines to make predictions, classify data, or make decisions based on data.
#
# The basic idea behind machine learning is to provide a system with a dataset, which it can use to train an algorithm that can learn from the data. The system can then use this learned knowledge to make predictions or take actions in new, unseen situations.
#
# There are several key characteristics of machine learning:
#
# 1. **Data-driven**: Machine learning relies on large amounts of data to learn and improve.
# 2. **Unsupervised or supervised**: ML can be either unsupervised (learning from unlabeled data) or supervised (learning from labeled data).
# 3. **Self-improving**: The system improves its performance over time as it receives new data.
# 4. **Scalable**: Machine learning algorithms can handle large datasets and scale to meet the needs of modern applications.
#
# Machine learning has many applications, including:
#
# 1. **Image recognition**: Facial recognition, object detection, and image classification.
# 2. **Natural Language Processing (NLP)**: Sentiment analysis, language translation, and text summarization.
# 3. **Predictive modeling**: Forecasting sales, predicting customer churn, and identifying potential risks.
# 4. **Speech recognition**: Voice assistants, speech-to-text systems, and voice-controlled interfaces.
#
# Some popular types of machine learning include:
#
# 1. **Supervised learning**: Linear regression, logistic regression, decision trees, and random forests.
# 2. **Unsupervised learning**: Clustering algorithms (k-means, hierarchical clustering), dimensionality reduction (PCA, t-SNE).
# 3. **Reinforcement learning**: Learning to optimize rewards or penalties through trial and error.
#
# The benefits of machine learning include:
#
# 1. **Improved accuracy**: Machine learning can lead to more accurate predictions and decisions.
# 2. **Increased efficiency**: Automated processes can save time and resources.
# 3. **Scalability**: ML algorithms can handle large amounts of data, making them suitable for big data applications.
# 4. **Personalization**: Machine learning enables systems to adapt to individual users' needs.
#
# However, machine learning also has its challenges, including:
#
# 1. **Data quality issues**: Poor or biased data can lead to inaccurate predictions and decisions.
# 2. **Overfitting**: Models may become too specialized to the training data, leading to poor performance on new data.
# 3. **Explainability**: It's often difficult to understand why a machine learning model made a particular decision.
#
# Overall, machine learning has revolutionized many industries by enabling systems to learn and improve from experience. Its applications continue to grow as the amount of available data increases.
# Here's a real-world example:
#
# **Example: Image Recognition with Facebook's Facial Detection**
#
# Facebook uses machine learning algorithms to detect faces in images uploaded by its users. Here's how it works:
#
# 1. **Data Collection**: Facebook collects a massive dataset of images, including photos of people and objects.
# 2. **Training**: The company trains a machine learning algorithm on this dataset to learn the patterns and features that distinguish different faces from one another.
# 3. **Model Development**: Facebook develops a deep neural network (DNN) architecture, which is a type of ML model, to analyze images.
# 4. **Testing**: The DNN is tested on new images uploaded by users to see how well it can detect faces.
#
# **How it Works**
#
# When you upload an image to Facebook and tag your friends in the photo, the algorithm works as follows:
#
# 1. **Image Preprocessing**: The image is preprocessed to enhance its quality and remove noise.
# 2. **Face Detection**: The DNN detects faces in the image using a combination of features such as skin tone, hair color, and facial structure.
# 3. **Face Recognition**: Once a face is detected, the algorithm checks it against the database of known faces to identify who's in the photo.
#
# **Benefits**
#
# This system has several benefits:
#
# 1. **Improved User Experience**: Facebook can provide users with accurate information about their friends' photos and help them tag people they know.
# 2. **Increased Efficiency**: The facial detection algorithm saves time and effort for users, making it easier for them to share content with others.
# 3. **Scalability**: The system can handle large amounts of data and scale to meet the needs of Facebook's vast user base.
#
# **Real-World Impact**
#
# Facebook's facial detection technology has had a significant impact on social media platforms:
#
# 1. **Increased User Engagement**: By allowing users to easily tag friends in photos, Facebook increased user engagement and encouraged more sharing.
# 2. **Personalization**: The algorithm enabled Facebook to provide users with personalized content recommendations based on their interests.
# 3. **Improved Customer Service**: Facebook's facial detection technology also improved its customer service by enabling it to identify and respond to user requests more efficiently.
#
# This example illustrates how machine learning is being used in real-world applications to solve complex problems, improve efficiency, and enhance the user experience.

# %%
# System Prompt
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"system",
            "content":"You are a computer science professor."
        },
        {
            "role":"user",
            "content":"Explain recursion."
        }
    ]
)

print(response["message"]["content"])
# Out:
# Recursion! One of the fundamental concepts in computer science that can be both fascinating and challenging to grasp.
#
# **What is Recursion?**
#
# Recursion is a programming technique where a function calls itself repeatedly until it reaches a base case that stops the recursion. In other words, a recursive function solves a problem by breaking it down into smaller instances of the same problem, which are then solved by the same function, until the solution to the original problem is found.
#
# **Key Characteristics of Recursion**
#
# 1. **Base Case**: A recursive function must have a base case that stops the recursion when a certain condition is met.
# 2. **Recursive Call**: The function calls itself with different inputs or parameters until it reaches the base case.
# 3. **Solution**: The final solution to the problem is found by solving smaller instances of the same problem.
#
# **How Recursion Works**
#
# Let's consider an example: calculating the factorial of a number using recursion.
#
# ```python
# def factorial(n):
#     if n == 0 or n == 1:
#         # Base Case: Return 1 when n is 0 or 1
#         return 1
#     else:
#         # Recursive Call: Calculate factorial of (n-1) and multiply by n
#         return n * factorial(n-1)
# ```
#
# In this example:
#
# * We define a function `factorial` that takes an integer `n` as input.
# * When `n` is 0 or 1, we return 1, which is the base case.
# * For all other values of `n`, we call `factorial(n-1)` and multiply the result by `n`. This is the recursive call.
#
# The recursion continues until `n` reaches 0 or 1, at which point the base case is reached, and the function starts returning values back up the call stack.
#
# **Example Walkthrough**
#
# Let's calculate the factorial of 4 using our recursive function:
#
# ```
# factorial(4) = 4 * factorial(3)
#              = 4 * (3 * factorial(2))
#              = 4 * (3 * (2 * factorial(1)))
#              = 4 * (3 * (2 * 1))
#              = 4 * 6
#              = 24
# ```
#
# As you can see, the recursive function calls itself repeatedly until it reaches the base case (`n` is 0 or 1), at which point the solution to the problem is found.
#
# **Common Pitfalls in Recursion**
#
# While recursion can be a powerful technique for solving problems, there are some common pitfalls to watch out for:
#
# * **Stack Overflow**: If the recursive function calls itself too many times, it can cause a stack overflow error.
# * **Infinite Recursion**: If the base case is never reached, the function will continue calling itself indefinitely.
#
# **Conclusion**
#
# Recursion is a fundamental concept in computer science that involves breaking down problems into smaller instances of the same problem. By understanding recursion and how to use it effectively, you can solve complex problems in a elegant and efficient way.

# %%
# System prompt
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"system",
            "content":"You are a computer science professor."
        },
        {
            "role":"user",
            "content":"Explain recursion."
        }
    ]
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # System prompt
# ----> 2 response = chat(
#       3     model="llama3.2:3b",
#       4     messages=[
#       5         {
#
# NameError: name 'chat' is not defined

# %%
# Zero-shot prompting
prompt = """
Classify the sentiment.

Sentence:
The lecture was excellent.
"""

response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":prompt
        }
    ]
)

print(response["message"]["content"])
# Out:
# The sentiment of this sentence is POSITIVE. The use of the word "excellent" indicates a strong favorable opinion about the lecture.

# %%
# One-shot prompting
prompt = """
Example

Sentence:
The movie was fantastic.

Sentiment:
Positive

Sentence:
The assignment was confusing.

Sentiment:
"""

response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":prompt
        }
    ]
)

print(response["message"]["content"])
# Out:
# Negative

# %%
# Few shot prompting
prompt = """
Example 1

The food was delicious.

Positive

Example 2

The service was terrible.

Negative

Example 3

The class starts at 10 AM.

Neutral

Sentence

The exam was difficult but fair.

Sentiment
"""

response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":prompt
        }
    ]
)

print(response["message"]["content"])
# Out:
# To analyze the sentiment of a sentence, you need to determine if it has a positive, negative, or neutral tone. Here's how you can do it:
#
# 1. Check the words: Look for words like "love," "great," "happy," "good," and "delicious." These words often indicate a positive sentiment.
#
# 2. Identify phrases with positive adjectives: Phrases like "incredibly good," "excellent," or "wonderful" usually have a positive tone.
#
# 3. Check for positive nouns: Words like "beautiful," "great," or "awesome" can also signal a positive sentiment.
#
# 4. Look at the context: Consider the situation and the reason behind your emotions. If you're expressing gratitude, it might be positive.
#
# 5. Identify phrases with negative adjectives: Phrases like "bad," "awful," "terrible," or "unhappy" usually have a negative tone.
#
# 6. Check for negative nouns: Words like "horrible," "bad," or "awful" can also signal a negative sentiment.
#
# 7. Look at the context: Consider the situation and the reason behind your emotions. If you're expressing frustration, it might be negative.
#
# Now, let's analyze the given examples:
#
# Example 1: The food was delicious.
#  Positive
#
# Example 2: The service was terrible.
#  Negative
#
# Example 3: The class starts at 10 AM.
#  Neutral

# %%
# Temperature
from ollama import chat

response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"Suggest five startup ideas using AI."
        }
    ],
    options={
        "temperature":0.2
    }
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Temperature
# ----> 2 from ollama import chat
#       3
#       4 response = chat(
#       5     model="llama3.2:3b",
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# Higher Temperature
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"Suggest five startup ideas using AI."
        }
    ],
    options={
        "temperature":0.2
    }
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Higher Temperature
# ----> 2 response = chat(
#       3     model="llama3.2:3b",
#       4     messages=[
#       5         {
#
# NameError: name 'chat' is not defined

# %%
# Top p
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"Write a short fantasy story."
        }
    ],
    options={
        "top_p":0.6
    }
)

print(response["message"]["content"])
# Out:
# In the realm of Aethereia, where the skies were painted with hues of sapphire and amethyst, the village of Luminaria lay nestled within a valley of whispering trees. It was a place of ancient magic, where the air was sweet with the scent of moonflowers and the sound of soft chanting carried on the breeze.
#
# Aria, a young apprentice to the village's revered sorceress, Lyra, possessed a gift that set her apart from the rest. She could hear the whispers of the forest, the trees themselves speaking to her in a language only she could understand.
#
# One fateful evening, as the sun dipped into the horizon, Aria felt an unusual resonance within the forest. The trees seemed to be calling to her, their whispers growing urgent and insistent. Lyra, sensing Aria's distress, appeared beside her, her eyes shining with a knowing light.
#
# "The ancient ones stir," Lyra whispered, her voice barely audible over the rustling of leaves. "The balance of nature is shifting, and the forest is warning us of an impending catastrophe."
#
# Aria's heart pounded as she listened to the trees' whispers, their words weaving together into a tale of a long-forgotten ritual that had been hidden for centuries. The ancient ones, powerful beings who had once ruled Aethereia, were said to have harnessed the very essence of the forest to maintain harmony and balance.
#
# But as Lyra explained, a dark force had corrupted their magic, shattering the delicate equilibrium of nature. Now, the land itself was crying out for restoration, and only Aria's unique gift could help unlock the secrets of the ancient ritual.
#
# With Lyra by her side, Aria set out into the forest, following the whispers that led them to a hidden glade. There, they discovered an ancient stone pedestal, upon which rested a glowing crystal. The trees' whispers grew louder still, urging Aria to claim the crystal and channel its power.
#
# As she reached for the crystal, Aria felt a surge of energy course through her veins. She raised her hands, and the forest responded, its magic surging forth in a spectacular display of light and color. The ancient ritual was rekindled, and with it, the balance of nature began to shift once more.
#
# The darkness receded, and the land began to heal. Aria's gift had unlocked the secrets of the ancient ones, restoring harmony to the realm of Aethereia. As she stood amidst the forest's renewed vitality, Lyra smiled, her eyes shining with pride.
#
# "You have truly become a guardian of this land, Aria," Lyra said, her voice filled with warmth. "The whispers of the trees will always be your guide, and together, we will maintain the balance of nature, ensuring that Aethereia remains a haven of wonder and magic for generations to come."

# %%
# Max tokens
response = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"Explain Neural Networks."
        }
    ],
    options={
        "num_predict":40
    }
)

print(response["message"]["content"])
# Out:
# Neural networks are a fundamental concept in machine learning and artificial intelligence. They are designed to mimic the structure and function of the human brain, allowing computers to learn from data and improve their performance on complex

# %%
# streaming output
from ollama import chat

stream = chat(
    model="llama3.2:3b",
    messages=[
        {
            "role":"user",
            "content":"Explain Generative AI."
        }
    ],
    stream=True
)

for chunk in stream:
    print(chunk["message"]["content"], end="", flush=True)
# Out:
# Generative AI (Artificial Intelligence) is a type of machine learning technology that enables the creation of new, original data, such as images, music, text, and videos, by generating them based on patterns learned from existing datasets.
#
# The goal of generative AI is to create something entirely new, rather than just modifying or improving an existing piece of content. This can be achieved through various techniques, including:
#
# 1. **Deep learning**: Generative AI models are often built using deep neural networks, which are capable of learning complex patterns in data.
# 2. **Generative adversarial networks (GANs)**: GANs consist of two neural networks that work together to generate new data. One network generates the new data, while the other network evaluates its quality and provides feedback.
# 3. **Variational autoencoders (VAEs)**: VAEs are a type of generative model that learn to compress and decompress data, allowing for the generation of new data.
#
# Generative AI has numerous applications across various industries, including:
#
# 1. **Computer vision**: Generating realistic images and videos from scratch.
# 2. **Music generation**: Creating original music tracks based on patterns learned from existing music datasets.
# 3. **Text generation**: Producing coherent and natural-sounding text based on language models.
# 4. **Data augmentation**: Generating new data to augment existing datasets, making them more diverse and representative.
#
# Some examples of generative AI include:
#
# 1. **Deepfakes**: AI-generated videos or images that mimic real people's faces and movements.
# 2. **Art generators**: Tools like Generative Adversarial Networks (GANs) that can create original art pieces based on user input.
# 3. **Music composition tools**: Software that uses generative models to compose music tracks.
#
# The benefits of generative AI include:
#
# 1. **Increased creativity**: Generative AI can generate new and innovative ideas, products, or services.
# 2. **Improved efficiency**: Automating repetitive tasks and generating data can save time and resources.
# 3. **Enhanced customer experience**: Personalized content and experiences can be generated using generative AI.
#
# However, there are also concerns surrounding the use of generative AI, such as:
#
# 1. **Authenticity**: The line between real and fake content can become blurred.
# 2. **Bias and fairness**: Generative models may perpetuate existing biases and inequalities if they are trained on biased data.
# 3. **Job displacement**: Generative AI could automate jobs that require creative or repetitive tasks.
#
# Overall, generative AI has the potential to revolutionize various industries by generating new content, improving efficiency, and enhancing customer experiences.

# %%
# Simple chatbot
history = [
    {
        "role":"system",
        "content":"You are a helpful AI teaching assistant."
    }
]

while True:

    user = input("You: ")

    if user.lower() == "exit":
        break

    history.append(
        {
            "role":"user",
            "content":user
        }
    )

    response = chat(
        model="llama3.2:3b",
        messages=history
    )

    answer = response["message"]["content"]

    print("\nAssistant:", answer)

    history.append(
        {
            "role":"assistant",
            "content":answer
        }
    )
# Out:
# You:  tell me a joke
# Assistant: Why don't eggs tell jokes?
#
# Because they'd crack each other up!
# You:
# Assistant: I've got another one:
#
# What do you call a fake noodle?
#
# An impasta!
#
# Want to hear another?
# You:  quit
# Assistant: No more jokes for now. Have a good day!
# You:  exit
